# %%
weight = 0.5
input = 0.5
goalPred = 0.8

# %%
pred = input * weight
error = (pred - goalPred) ** 2

# %%
print(pred)
print(error)
# Out:
# 0.25
# 0.30250000000000005

# %%
def hac():
# Out:
# 3.623898318388478
